# %%
import warnings
warnings.filterwarnings("ignore")

import os
from os.path import join

import pandas as pd
import numpy as np

import missingno

from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import KFold, cross_val_score
import xgboost as xgb
import lightgbm as lgb

import matplotlib.pyplot as plt
import seaborn as sns

# %%
#server path
data_dir = os.getenv('HOME')+'/aiffel/kaggle_kakr_housing/data'

train_data_path = join(data_dir, 'train.csv')
sub_data_path = join(data_dir, 'test.csv')

# %%
#local path
print(os.getcwd())
#train_data_path = "/mnt/c/github/AIFFEL/exp06/data/train.csv"
#sub_data_path = "/mnt/c/github/AIFFEL/exp06/data/test.csv"
# Out:
# /aiffel

# %%
train = pd.read_csv(train_data_path)
test = pd.read_csv(sub_data_path)
print('train data dim : {}' .format(train.shape))
print('test data dim : {}' .format(test.shape))
# Out:
# train data dim : (15035, 21)
# test data dim : (6468, 20)

# %%
train
# Out:
#           id             date      price  bedrooms  bathrooms  sqft_living  \
# 0          0  20141013T000000   221900.0         3       1.00         1180
# 1          1  20150225T000000   180000.0         2       1.00          770
# 2          2  20150218T000000   510000.0         3       2.00         1680
# 3          3  20140627T000000   257500.0         3       2.25         1715
# 4          4  20150115T000000   291850.0         3       1.50         1060
# ...      ...              ...        ...       ...        ...          ...
# 15030  15030  20141014T000000   610685.0         4       2.50         2520
# 15031  15031  20150326T000000  1007500.0         4       3.50         3510
# 15032  15032  20140521T000000   360000.0         3       2.50         1530
# 15033  15033  20150223T000000   400000.0         4       2.50         2310
# 15034  15034  20141015T000000   325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
train.describe(include='all')
# Out:
#                   id             date         price      bedrooms  \
# count   15035.000000            15035  1.503500e+04  15035.000000
# unique           NaN              365           NaN           NaN
# top              NaN  20140623T000000           NaN           NaN
# freq             NaN              101           NaN           NaN
# mean     7517.000000              NaN  5.406827e+05      3.369139
# std      4340.374984              NaN  3.715247e+05      0.902721
# min         0.000000              NaN  7.800000e+04      0.000000
# 25%      3758.500000              NaN  3.220000e+05      3.000000
# 50%      7517.000000              NaN  4.500000e+05      3.000000
# 75%     11275.500000              NaN  6.450000e+05      4.000000
# max     15034.000000              NaN  7.700000e+06     10.000000
#
#            bathrooms   sqft_living      sqft_lot        floors    waterfront  \
# count   15035.000000  15035.000000  1.503500e+04  15035.000000  15035.000000
# ...

# %%
test
# Out:
#          id             date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0     15035  20141209T000000         3       2.25         2570      7242
# 1     15036  20141209T000000         4       3.00         1960      5000
# 2     15037  20140512T000000         4       4.50         5420    101930
# 3     15038  20150415T000000         3       1.00         1780      7470
# 4     15039  20150312T000000         3       2.50         1890      6560
# ...     ...              ...       ...        ...          ...       ...
# 6463  21498  20140626T000000         3       1.75         1500     11968
# 6464  21499  20150126T000000         3       2.00         1490      1126
# 6465  21500  20150219T000000         3       2.50         1310      1294
# 6466  21501  20140623T000000         2       0.75         1020      1350
# 6467  21502  20150116T000000         3       2.50         1600      2388
#
#       floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %%
train_len = len(train)

price= train['price']
id = test['id']

data = pd.concat((train, test), axis = 0)

print("data size is: {}" .format(data.shape))
# Out:
# data size is: (21503, 21)

# %%
print(type(price))
price
# Out:
# <class 'pandas.core.series.Series'>
# 0         221900.0
# 1         180000.0
# 2         510000.0
# 3         257500.0
# 4         291850.0
#            ...
# 15030     610685.0
# 15031    1007500.0
# 15032     360000.0
# 15033     400000.0
# 15034     325000.0
# Name: price, Length: 15035, dtype: float64

# %%
data.head()
# Out:
#    id             date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0   0  20141013T000000  221900.0         3       1.00         1180      5650
# 1   1  20150225T000000  180000.0         2       1.00          770     10000
# 2   2  20150218T000000  510000.0         3       2.00         1680      8080
# 3   3  20140627T000000  257500.0         3       2.25         1715      6819
# 4   4  20150115T000000  291850.0         3       1.50         1060      9711
#
#    floors  waterfront  view  ...  grade  sqft_above  sqft_basement  yr_built  \
# 0     1.0           0     0  ...      7        1180              0      1955
# 1     1.0           0     0  ...      6         770              0      1933
# 2     1.0           0     0  ...      8        1680              0      1987
# 3     2.0           0     0  ...      7        1715              0      1995
# 4     1.0           0     0  ...      7        1060              0      1963
#
# ...

# %% [markdown]
# # 전처리

# %% [markdown]
# id 제거, date 정리

# %%
sub_id = data['id'][train_len:]
del data['id']
data['date'] = data['date'].apply(lambda x : str(x[:6])).astype(str)

# %%
data.head()
# Out:
#      date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  201410  221900.0         3       1.00         1180      5650     1.0
# 1  201502  180000.0         2       1.00          770     10000     1.0
# 2  201502  510000.0         3       2.00         1680      8080     1.0
# 3  201406  257500.0         3       2.25         1715      6819     2.0
# 4  201501  291850.0         3       1.50         1060      9711     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      6         770              0      1933
# 2           0     0          3      8        1680              0      1987
# 3           0     0          3      7        1715              0      1995
# 4           0     0          3      7        1060              0      1963
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# ...

# %% [markdown]
# 결측치 확인

# %%
missingno.matrix(data, figsize=(15, 8))
# Out:
# <AxesSubplot:>

# %% [markdown]
# 치우친 값 정규화

# %%
skew_columns = ['bedrooms', 'sqft_living', 'sqft_lot', 'sqft_above', 'sqft_basement']

for c in skew_columns:
    data[c] = np.log1p(data[c].values)

# %%
fig, ax = plt.subplots(3, 2, figsize=(10, 15))

count = 0
for row in range(3):
    for col in range(2):
        if count == 5:
            break
        sns.kdeplot(data[skew_columns[count]], ax=ax[row][col])
        ax[row][col].set_title(skew_columns[count], fontsize=15)
        count+=1

# %%
sub = data.iloc[train_len:, :]
x = data.iloc[:train_len, :]

# %% [markdown]
# ## 상관관계 분석
# 1. ID : 집을 구분하는 번호
# 2. date : 집을 구매한 날짜
# 3. price : 타겟 변수인 집의 가격
# 4. bedrooms : 침실의 수
# 5. bathrooms : 침실당 화장실 개수
# 6. sqft_living : 주거 공간의 평방 피트
# 7. sqft_lot : 부지의 평방 피트
# 8. floors : 집의 층 수
# 9. waterfront : 집의 전방에 강이 흐르는지 유무 (a.k.a. 리버뷰)
# 10. view : 집이 얼마나 좋아 보이는지의 정도
# 11. condition : 집의 전반적인 상태
# 12. grade : King County grading 시스템 기준으로 매긴 집의 등급
# 13. sqft_above : 지하실을 제외한 평방 피트
# 14. sqft_basement : 지하실의 평방 피트
# 15. yr_built : 집을 지은 년도
# 16. yr_renovated : 집을 재건축한 년도
# 17. zipcode : 우편번호
# 18. lat : 위도
# 19. long : 경도
# 20. sqft_living15 : 2015년 기준 주거 공간의 평방 피트(집을 재건축했다면, 변화가 있을 수 있음)
# 21. sqft_lot15 : 2015년 기준 부지의 평방 피트(집을 재건축했다면, 변화가 있을 수 있음)

# %%
data
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0     201410  221900.0  1.386294       1.00     7.074117  8.639588     1.0
# 1     201502  180000.0  1.098612       1.00     6.647688  9.210440     1.0
# 2     201502  510000.0  1.386294       2.00     7.427144  8.997271     1.0
# 3     201406  257500.0  1.386294       2.25     7.447751  8.827615     2.0
# 4     201501  291850.0  1.386294       1.50     6.966967  9.181118     1.0
# ...      ...       ...       ...        ...          ...       ...     ...
# 6463  201406       NaN  1.386294       1.75     7.313887  9.390075     1.0
# 6464  201501       NaN  1.386294       2.00     7.307202  7.027315     3.0
# 6465  201502       NaN  1.386294       2.50     7.178545  7.166266     2.0
# 6466  201406       NaN  1.098612       0.75     6.928538  7.208600     2.0
# 6467  201501       NaN  1.386294       2.50     7.378384  7.778630     2.0
#
# ...

# %%
data.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21503 entries, 0 to 6467
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           21503 non-null  object
#  1   price          15035 non-null  float64
#  2   bedrooms       21503 non-null  float64
#  3   bathrooms      21503 non-null  float64
#  4   sqft_living    21503 non-null  float64
#  5   sqft_lot       21503 non-null  float64
#  6   floors         21503 non-null  float64
#  7   waterfront     21503 non-null  int64
#  8   view           21503 non-null  int64
#  9   condition      21503 non-null  int64
#  10  grade          21503 non-null  int64
#  11  sqft_above     21503 non-null  float64
#  12  sqft_basement  21503 non-null  float64
#  13  yr_built       21503 non-null  int64
#  14  yr_renovated   21503 non-null  int64
#  15  zipcode        21503 non-null  int64
#  16  lat            21503 non-null  float64
# ...

# %%
#co-relaton 매트릭스
corr = train.corr()

#0으로된 매트릭스를 마스크에 붙임
#corr에서 관계숫자 만들기, mask는 같은 모양 매트릭스
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

plt.figure(figsize = (14, 8))

plt.title('Overall Correlation of House Features', fontsize=18)

#매트릭스 런칭
sns.heatmap(corr, mask=mask, annot=False, cmap='RdYlGn', linewidths=0.2, annot_kws={'size':20})
plt.show()

# %% [markdown]
# ## corelation이 높지않은 column 제거
# grade, sqft_living15, bathrooms, sqft_above, sqft_living, bedrooms 와 예측해야하는 값인 price만 남긴다

# %%
good_col = ['price', 'grade', 'sqft_living15', 'bathrooms', 'sqft_above', 'sqft_living', 'bedrooms']
f_data = pd.DataFrame()
f_data[good_col] = train[good_col]

f_data
# Out:
#            price  grade  sqft_living15  bathrooms  sqft_above  sqft_living  \
# 0       221900.0      7           1340       1.00        1180         1180
# 1       180000.0      6           2720       1.00         770          770
# 2       510000.0      8           1800       2.00        1680         1680
# 3       257500.0      7           2238       2.25        1715         1715
# 4       291850.0      7           1650       1.50        1060         1060
# ...          ...    ...            ...        ...         ...          ...
# 15030   610685.0      9           2520       2.50        2520         2520
# 15031  1007500.0      9           2050       3.50        2600         3510
# 15032   360000.0      8           1530       2.50        1530         1530
# 15033   400000.0      8           1830       2.50        2310         2310
# 15034   325000.0      7           1020       0.75        1020         1020
#
#        bedrooms
# 0             3
# 1             2
# ...

# %%
corr = f_data[:train_len].corr()

mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

plt.figure(figsize = (14, 8))

plt.title('Overall Correlation of House Features', fontsize=18)

sns.heatmap(corr, mask=mask, annot=False, cmap='RdYlGn', linewidths=0.2, annot_kws={'size':20})
plt.show()

# %% [markdown]
# # TODO
# ## 각 요소별 eda
# * bathroom 4 곱하기
# * 구간화
#
# ## 새로운 요소
# grade : 집의 등급
# sqft_living15 : 2015년기준 평수
# sqft_above : 지하실 제외한 평수
#
# -> thinking.. 평수 정보들을 합칠 수 있지 않을까?

# %%
# check sqft living
train['sqft_living'].head()
# Out:
# 0    1180
# 1     770
# 2    1680
# 3    1715
# 4    1060
# Name: sqft_living, dtype: int64

# %%
# check price
train['price'].head()
# Out:
# 0    221900.0
# 1    180000.0
# 2    510000.0
# 3    257500.0
# 4    291850.0
# Name: price, dtype: float64

# %%
t_sqft = train['sqft_living'][:500]
t_price = train['price'][:500]

# %%
sns.swarmplot(x=t_sqft, y=t_price)
plt.xlabel('Sqft_living')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# ## Bathrooms

# %%
def piecount(col):
    f, ax = plt.subplots(1, 2, figsize=(12, 6))
    f_data[col].value_counts().plot.pie(explode=[0.1 for i in range(f_data[col].nunique())], autopct='%1.1f%%', ax=ax[0], shadow=True)
    ax[0].set_title(col)
    ax[0].set_ylabel('')
    sns.countplot(col, data=f_data, ax=ax[1])
    ax[1].set_title(col)
    plt.show()

# %%
piecount('bathrooms')

# %% [markdown]
# float 형태인 데이터를 int 형태로 바꿔주자

# %%
f_data['bath'] = f_data['bathrooms'].apply(lambda x: int(4 * x))
f_data['bath'].head()
# Out:
# 0    4
# 1    4
# 2    8
# 3    9
# 4    6
# Name: bath, dtype: int64

# %%
f_data['bathrooms'].head()
# Out:
# 0    1.00
# 1    1.00
# 2    2.00
# 3    2.25
# 4    1.50
# Name: bathrooms, dtype: float64

# %%
piecount('bath')

# %% [markdown]
# ## sqft

# %%
print ("highest: ", f_data['sqft_living'].max())
print ("lowest: ", f_data['sqft_living'].min())
print ("average: ", f_data['sqft_living'].mean())
# Out:
# highest:  13540
# lowest:  290
# average:  2083.7902228134353

# %%
f, ax = plt.subplots(1, 3, figsize=(20, 6))
sns.distplot(f_data['sqft_living'], ax=ax[0])
sns.distplot(f_data['sqft_living15'], ax=ax[1])
sns.distplot(f_data['sqft_above'], ax=ax[2])
plt.show()

# %%
del f_data['bathrooms']
f_data.head()
# Out:
#       price  grade  sqft_living15  sqft_above  sqft_living  bedrooms  bath
# 0  221900.0      7           1340        1180         1180         3     4
# 1  180000.0      6           2720         770          770         2     4
# 2  510000.0      8           1800        1680         1680         3     8
# 3  257500.0      7           2238        1715         1715         3     9
# 4  291850.0      7           1650        1060         1060         3     6

# %%
sub = f_data.iloc[train_len:, :]
x = f_data.iloc[:train_len, :]
y = x['price']

# %%
x.head()
# Out:
#       price  grade  sqft_living15  sqft_above  sqft_living  bedrooms  bath
# 0  221900.0      7           1340        1180         1180         3     4
# 1  180000.0      6           2720         770          770         2     4
# 2  510000.0      8           1800        1680         1680         3     8
# 3  257500.0      7           2238        1715         1715         3     9
# 4  291850.0      7           1650        1060         1060         3     6

# %%
y.head()
# Out:
# 0    221900.0
# 1    180000.0
# 2    510000.0
# 3    257500.0
# 4    291850.0
# Name: price, dtype: float64

# %%
del x['price']
x.tail()
# Out:
#        grade  sqft_living15  sqft_above  sqft_living  bedrooms  bath
# 15030      9           2520        2520         2520         4    10
# 15031      9           2050        2600         3510         4    14
# 15032      8           1530        1530         1530         3    10
# 15033      8           1830        2310         2310         4    10
# 15034      7           1020        1020         1020         2     3

# %%
'''
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_train = scaler.fit_transform(x)

print(x_train.shape)
'''
# Out:
# '\nfrom sklearn.preprocessing import StandardScaler\n\nscaler = StandardScaler()\nx_train = scaler.fit_transform(x)\n\nprint(x_train.shape)\n'

# %% [markdown]
# # 3. Modeling

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor

from sklearn.model_selection import GridSearchCV

# %%
def rmse(y_test, y_pred):
    return np.sqrt(mean_squared_error(np.expm1(y_test), np.expm1(y_pred)))

# %%
random_state = 42

gboost=GradientBoostingRegressor(random_state=random_state)
xgboost=XGBRegressor(random_state=random_state)
lightgbm=LGBMRegressor(random_state=random_state)
rdforest=RandomForestRegressor(random_state=random_state)

models = [gboost, xgboost, lightgbm, rdforest]
model_names = ['gboost', 'xgboost', 'lightgbm', 'randomforest']
scores = {}

# %%
# 이어서 연속적으로 모델을 학습 시키고 교차 검증합니다.
for ind, model in enumerate(models):
    X_train, X_test, y_train, y_test = train_test_split(x, y, random_state=random_state, test_size=0.2)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    print(y_pred)
    acc = rmse(y_test, y_pred)
    scores[model_names[ind]] = acc
    score_df = pd.DataFrame(scores, index=['RMSE']).T.sort_values('RMSE', ascending=False)
# Out:
# [336381.8847204  402849.63499466 354494.57266923 ... 278891.17483443
#  496355.55002803 352498.43055477]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-113-e16022f45955> in <module>
#       6
#       7     print(y_pred)
# ----> 8     acc = rmse(y_test, y_pred)
#       9     scores[model_names[ind]] = acc
#      10     score_df = pd.DataFrame(scores, index=['RMSE']).T.sort_values('RMSE', ascending=False)
#
# <ipython-input-105-860886fe769f> in rmse(y_test, y_pred)
#       1 def rmse(y_test, y_pred):
# ----> 2     return np.sqrt(mean_squared_error(np.expm1(y_test), np.expm1(y_pred)))
#       3
#
# /opt/conda/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
# ...

# %%
def get_scores(models, train, y):
    df = {}

    for model in models:
        model_name = model.__class__.__name__

        X_train, X_test, y_train, y_test = train_test_split(train, y, random_state=random_state, test_size=0.2)
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)

        df[model_name] = rmse(y_test, y_pred)
        score_df = pd.DataFrame(df, index=['RMSE']).T.sort_values('RMSE', ascending=False)

# %%
def get_scores(models, train, y):
    df = {}

    for model in models:
        model_name = model.__class__.__name__

        X_train, X_test, y_train, y_test = train_test_split(train, y, random_state=random_state, test_size=0.2)
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)

        df[model_name] = rmse(y_test, y_pred)
        score_df = pd.DataFrame(df, index=['RMSE']).T.sort_values('RMSE', ascending=False)

# %%
get_scores(models, x, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-109-a4f0174b46c5> in <module>
# ----> 1 get_scores(models, x, y)
#       2
#
# <ipython-input-107-3212f11b8076> in get_scores(models, train, y)
#       9         y_pred = model.predict(X_test)
#      10
# ---> 11         df[model_name] = rmse(y_test, y_pred)
#      12         score_df = pd.DataFrame(df, index=['RMSE']).T.sort_values('RMSE', ascending=False)
#      13
#
# <ipython-input-105-860886fe769f> in rmse(y_test, y_pred)
#       1 def rmse(y_test, y_pred):
# ----> 2     return np.sqrt(mean_squared_error(np.expm1(y_test), np.expm1(y_pred)))
#       3
#
# /opt/conda/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ...

# %%
param_grid={
    'n_estimators': [50, 100],
    'max_depth': [1, 10],
}

# %%
grid_model = GridSearchCV(model, param_grid=param_grid,
                          scoring='neg_mean_squared_error',
                          cv=5, verbose=1, n_jobs=5)

# %%
def GridSearch(model, train, y, param_grid, verbose=2, n_jobs=5):
    grid_model=GridSearchCV(model, param_grid=param_grid,
                            scoring='neg_mean_squared_error',
                            cv=5, verbose=verbose, n_jobs=n_jobs)

    grid_model.fit(train, y)

    params = grid_model.cv_results_['params']
    score = grid_model.cv_results_['mean_test_score']

    results = pd.DataFrame(params)
    results['score'] = score

    results['RMSLE'] = np.squrt(-1 * results['score'])
    results = results.sort_values('RMSLE')

    return results
